# %% [markdown]
# # Experiments
#
# This notebook contains the code for running the model training for the experiments described in  5 of the documentation. This notebook is adapted to run on Google Colab connected to the A100 GPU.

# %%
# clone forked ULTRA repository with updated datasets.py
# !git clone https://github.com/cora-hai/ULTRA
# Out:
# Cloning into 'ULTRA'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 146 (delta 66), reused 65 (delta 55), pack-reused 48 (from 1)
# Receiving objects: 100% (146/146), 7.62 MiB | 17.19 MiB/s, done.
# Resolving deltas: 100% (67/67), done.

# %%
# go to relevant directory
# %cd ULTRA
# Out:
# /content/ULTRA

# %%
# install requirements
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 81.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 23.4 MB/s eta 0:00:00
# ...

# %%
# get torch version
# !pip show torch
# Out:
# Name: torch
# Version: 2.8.0+cu126
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: filelock, fsspec, jinja2, networkx, nvidia-cublas-cu12, nvidia-cuda-cupti-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-runtime-cu12, nvidia-cudnn-cu12, nvidia-cufft-cu12, nvidia-cufile-cu12, nvidia-curand-cu12, nvidia-cusolver-cu12, nvidia-cusparse-cu12, nvidia-cusparselt-cu12, nvidia-nccl-cu12, nvidia-nvjitlink-cu12, nvidia-nvtx-cu12, setuptools, sympy, triton, typing-extensions
# Required-by: accelerate, fastai, peft, sentence-transformers, timm, torchaudio, torchdata, torchvision

# %%
# install correct version of torch-scatter (depending on which torch version is installed...)
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-2.8.0+cu126.html
# Out:
# Looking in links: https://data.pyg.org/whl/torch-2.8.0+cu126.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 155.3 MB/s eta 0:00:00
# ...

# %%
# run example for transductive dataset on GPU from the GitHub repository
# !python script/run.py -c config/transductive/inference.yaml --dataset CoDExSmall --epochs 0 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_4g.pth
# Out:
# 15:39:01   Random seed: 1024
# 15:39:01   Config file: config/transductive/inference.yaml
# 15:39:01   {'checkpoint': '/content/ULTRA/ckpts/ultra_4g.pth',
#  'dataset': {'class': 'CoDExSmall', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# run transductive inference with finetuning for 1 epoch on CoDEx Small
# !python script/run.py -c config/transductive/inference.yaml --dataset CoDExSmall --epochs 1 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_4g.pth --finetune --reps 5
# Out:
# 13:45:57   Random seed: 1024
# 13:45:57   Config file: config/transductive/inference.yaml
# 13:45:57   {'checkpoint': '/content/ULTRA/ckpts/ultra_4g.pth',
#  'dataset': {'class': 'CoDExSmall', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# transductive zero-shot inference on custom dataset PICKLE with 4g model
# !python script/run.py -c config/transductive/inference.yaml --dataset PICKLE --epochs 0 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_4g.pth
# Out:
# 15:40:44   Random seed: 1024
# 15:40:44   Config file: config/transductive/inference.yaml
# 15:40:44   {'checkpoint': '/content/ULTRA/ckpts/ultra_4g.pth',
#  'dataset': {'class': 'PICKLE', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# transductive inference with finetuning for 1 epoch on PICKLE with 4g
# !python script/run.py -c config/transductive/inference.yaml --dataset PICKLE --epochs 1 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_4g.pth --finetune --reps 5
# Out:
# 20:43:13   Random seed: 1024
# 20:43:13   Config file: config/transductive/inference.yaml
# 20:43:13   {'checkpoint': '/content/ULTRA/ckpts/ultra_4g.pth',
#  'dataset': {'class': 'PICKLE', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# transductive inference with finetuning for 5 epochs on PICKLE with 4g
# !python script/run.py -c config/transductive/inference.yaml --dataset PICKLE --epochs 5 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_4g.pth --finetune --reps 5
# Out:
# 20:44:29   Random seed: 1024
# 20:44:29   Config file: config/transductive/inference.yaml
# 20:44:29   {'checkpoint': '/content/ULTRA/ckpts/ultra_4g.pth',
#  'dataset': {'class': 'PICKLE', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# transductive inference with finetuning for 10 epochs on PICKLE with 4g
# !python script/run.py -c config/transductive/inference.yaml --dataset PICKLE --epochs 10 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_4g.pth --finetune --reps 5
# Out:
# 20:55:06   Random seed: 1024
# 20:55:06   Config file: config/transductive/inference.yaml
# 20:55:06   {'checkpoint': '/content/ULTRA/ckpts/ultra_4g.pth',
#  'dataset': {'class': 'PICKLE', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# transductive inference with finetuning for 20 epochs on PICKLE with 4g
# !python script/run.py -c config/transductive/inference.yaml --dataset PICKLE --epochs 20 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_4g.pth --finetune --reps 5
# Out:
# 20:45:33   Random seed: 1024
# 20:45:33   Config file: config/transductive/inference.yaml
# 20:45:33   {'checkpoint': '/content/ULTRA/ckpts/ultra_4g.pth',
#  'dataset': {'class': 'PICKLE', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# transductive zero-shot inference on PICKLE with 50g
# !python script/run.py -c config/transductive/inference.yaml --dataset PICKLE --epochs 0 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_50g.pth
# Out:
# 09:54:10   Random seed: 1024
# 09:54:10   Config file: config/transductive/inference.yaml
# 09:54:10   {'checkpoint': '/content/ULTRA/ckpts/ultra_50g.pth',
#  'dataset': {'class': 'PICKLE', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# transductive inference with finetuning for 1 epoch on PICKLE with 50g
# !python script/run.py -c config/transductive/inference.yaml --dataset PICKLE --epochs 1 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_50g.pth --finetune --reps 5
# Out:
# 20:48:13   Random seed: 1024
# 20:48:13   Config file: config/transductive/inference.yaml
# 20:48:13   {'checkpoint': '/content/ULTRA/ckpts/ultra_50g.pth',
#  'dataset': {'class': 'PICKLE', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# transductive inference with finetuning for 5 epochs on PICKLE with 50g
# !python script/run.py -c config/transductive/inference.yaml --dataset PICKLE --epochs 5 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_50g.pth --finetune --reps 5
# Out:
# 20:49:03   Random seed: 1024
# 20:49:03   Config file: config/transductive/inference.yaml
# 20:49:03   {'checkpoint': '/content/ULTRA/ckpts/ultra_50g.pth',
#  'dataset': {'class': 'PICKLE', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# transductive inference with finetuning for 10 epochs on PICKLE with 50g
# !python script/run.py -c config/transductive/inference.yaml --dataset PICKLE --epochs 10 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_50g.pth --finetune --reps 5
# Out:
# 20:50:36   Random seed: 1024
# 20:50:36   Config file: config/transductive/inference.yaml
# 20:50:36   {'checkpoint': '/content/ULTRA/ckpts/ultra_50g.pth',
#  'dataset': {'class': 'PICKLE', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# transductive inference with finetuning for 20 epochs on PICKLE with 50g
# !python script/run.py -c config/transductive/inference.yaml --dataset PICKLE --epochs 20 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_50g.pth --finetune --reps 5
# Out:
# 20:52:18   Random seed: 1024
# 20:52:18   Config file: config/transductive/inference.yaml
# 20:52:18   {'checkpoint': '/content/ULTRA/ckpts/ultra_50g.pth',
#  'dataset': {'class': 'PICKLE', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# transductive zero-shot inference on PICKLE with 3g
# !python script/run.py -c config/transductive/inference.yaml --dataset PICKLE --epochs 0 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_3g.pth
# Out:
# 09:59:17   Random seed: 1024
# 09:59:17   Config file: config/transductive/inference.yaml
# 09:59:17   {'checkpoint': '/content/ULTRA/ckpts/ultra_3g.pth',
#  'dataset': {'class': 'PICKLE', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# transductive inference with finetuning for 1 epoch on PICKLE with 3g
# !python script/run.py -c config/transductive/inference.yaml --dataset PICKLE --epochs 1 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_3g.pth --finetune --reps 5
# Out:
# 20:56:45   Random seed: 1024
# 20:56:45   Config file: config/transductive/inference.yaml
# 20:56:45   {'checkpoint': '/content/ULTRA/ckpts/ultra_3g.pth',
#  'dataset': {'class': 'PICKLE', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# transductive inference with finetuning for 5 epochs on PICKLE with 3g
# !python script/run.py -c config/transductive/inference.yaml --dataset PICKLE --epochs 5 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_3g.pth --finetune --reps 5
# Out:
# 20:57:07   Random seed: 1024
# 20:57:07   Config file: config/transductive/inference.yaml
# 20:57:07   {'checkpoint': '/content/ULTRA/ckpts/ultra_3g.pth',
#  'dataset': {'class': 'PICKLE', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# transductive inference with finetuning for 10 epochs on PICKLE with 3g
# !python script/run.py -c config/transductive/inference.yaml --dataset PICKLE --epochs 10 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_3g.pth --finetune --reps 5
# Out:
# 20:58:15   Random seed: 1024
# 20:58:15   Config file: config/transductive/inference.yaml
# 20:58:15   {'checkpoint': '/content/ULTRA/ckpts/ultra_3g.pth',
#  'dataset': {'class': 'PICKLE', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...

# %%
# transductive inference with finetuning for 20 epochs on PICKLE with 3g
# !python script/run.py -c config/transductive/inference.yaml --dataset PICKLE --epochs 20 --bpe null --gpus [0] --ckpt /content/ULTRA/ckpts/ultra_3g.pth --finetune --reps 5
# Out:
# 20:59:43   Random seed: 1024
# 20:59:43   Config file: config/transductive/inference.yaml
# 20:59:43   {'checkpoint': '/content/ULTRA/ckpts/ultra_3g.pth',
#  'dataset': {'class': 'PICKLE', 'root': '~/git/ULTRA/kg-datasets/'},
#  'model': {'class': 'Ultra',
#            'entity_model': {'aggregate_func': 'sum',
#                             'class': 'EntityNBFNet',
#                             'hidden_dims': [64, 64, 64, 64, 64, 64],
#                             'input_dim': 64,
#                             'layer_norm': True,
#                             'message_func': 'distmult',
#                             'short_cut': True},
#            'relation_model': {'aggregate_func': 'sum',
#                               'class': 'RelNBFNet',
#                               'hidden_dims': [64, 64, 64, 64, 64, 64],
#                               'input_dim': 64,
#                               'layer_norm': True,
#                               'message_func': 'distmult',
# ...
